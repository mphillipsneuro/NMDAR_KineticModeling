# %% [markdown]
# # 10 Ca2+ Memantine fit

# %% [markdown]
# First things first, compile your model file (.mod) so that it can be used by NEURON. This line needs to be run anytime you use a new MOD file for a simulation, or anytime you make changes directly to the text in the MOD file. If you do not recompile a MOD file after editing, your changes will not be noted by NEURON - NEURON will just use the version it knows, i.e., the old version that has been compiled.

# %%
#Compile MOD files. !nrnivmodl is a python command and PlaneMods is the subfolder 
# (located in the same folder as the notebook) containing the MOD files. The ! calls the script "nrnivmodl" and runs it. 
# Again, you don't need to run this unless it's the first time that this version of the MOD file is used.
# !nrnivmodl PlaneMods
# Out:
# /usr/bin/xcrun
# /Users/ElizabethN/Downloads/CDB_Fitting/10uM
# -n Mod files:
# -n  "PlaneMods/CaPlaneNMDARwMem_EN1.mod"
#
#
# COBJS=''
#  -> Compiling mod_func.c
# gcc -O2   -I.   -I/Users/ElizabethN/opt/anaconda3/lib/python3.8/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c mod_func.c -o mod_func.o
#  => LINKING shared library ./libnrnmech.dylib
# g++ -O2 -DVERSION_INFO='8.0.0' -std=c++11 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -fPIC  -I /Users/ElizabethN/opt/anaconda3/lib/python3.8/site-packages/neuron/.data/include -o ./libnrnmech.dylib -Wl,-install_name,@rpath/libnrnmech.dylib \
# 	  ./mod_func.o ./CaPlaneNMDARwMem_EN1.o  -L/Users/ElizabethN/opt/anaconda3/lib/python3.8/site-packages/neuron/.data/lib -lnrniv -Wl,-rpath,/Users/ElizabethN/opt/anaconda3/lib/python3.8/site-packages/neuron/.data/lib    -lreadline
# rm -f ./.libs/libnrnmech.so ; mkdir -p ./.libs ; cp ./libnrnmech.dylib ./.libs/libnrnmech.so
# Successfully created x86_64/special

# %% [markdown]
# # Import your python packages and give them easy to call names. Also load some NEURON functions now so you don't have to later.
# We are basically loading only the python packages and parts of the NEURON program that we need, which saves us memory and allows things to run faster without losing any functionality. This is one of the advantages python has over matlab.

# %%
import neuron # self-explanatory
from neuron import h, gui # NEURON libraries containing funtions that we will use 
import numpy as np # python library for math functions
import pandas as pd # python library for working with dataframes, i.e. spreadsheets/tables
import matplotlib.pyplot as plt # python library for plotting

# Load external files & initialize.
h.load_file("stdrun.hoc");
h.stdinit();
h.load_file("mulfit.hoc", "MulRunFitter")
h.load_file("stdgui.hoc")
# Out:
# 1.0

# %% [markdown]
# Load and visualize experimental data to be fit. Data is an averaged trace that has been decimated (factor of 10) to improve speed of fitting. The averaged trace was made using another notebook ("avtrace1") that I've provided. The time component and current component are saved as separate numpy arrays, then loaded into memory here as variables.

# %%
# Experimental Data
# Load the time array in seconds, convert to ms
timedec = np.load("timedec.npy")
expt = timedec * 1000

# Load current array
expi = np.load("avtrace10red.npy")

# Visualize the loaded experimental data
plt.figure(figsize=(10, 6))
plt.plot(expt, expi)
plt.xlabel('Time')
plt.ylabel('Current (pA)')
plt.show()
# Print the length of the concatenated trace
print("Length:", len(expi))
# Out:
# Length: 304328

# %%
# #EN peak adjustments
# timedec = np.load("timedec.npy")
# expt = timedec * 1000
# expi = np.load("avtrace10red.npy")

# time_peak = expt[500:10000]
# current_peak = expi[500:10000]

# # Visualize the peak
# plt.figure(figsize=(10, 6))
# plt.plot(time_peak, current_peak)
# plt.xlabel('Time')
# plt.ylabel('Current (pA)')
# #plt.xlim(750, 2500)
# #plt.ylim(-1.2, -0.8)
# plt.show()
# # Print the length of the concatenated trace
# #print("Length:", len(expi))

# %% [markdown]
# # Build the model.
# First, we create a cell and define some properties of the cell. The properties don't matter too much for our purposes.
# The cell is a simple ball model.

# %%
soma = h.Section(name='soma')

# %%
# properties of cell
soma.L = 50
soma.diam = 50
soma.Ra = 10 #ohm*cm
soma.cm = 1 #μF/cm^2

# %% [markdown]
# Next, we add our channels to the cell. "CaPlaneNMDARwMem" is the name of our previously compiled MOD file.
# Note - NEURON will not recognize the "mechanism" if the name given here is not the same as the name in the "POINT_PROCESS CaPlaneNMDARwMem" line in the MOD file.

# %%
# insert NMDARs
NMDAR = h.CaPlaneNMDARwMem(soma(0.5))

# %%
# dir(soma) # can show you that the channels have been added

# %% [markdown]
# Designate the variables you want to monitor for the simulation as "vectors", which is what NEURON calls arrays. These variables are either global (time) or specific to the object you specify. Available variables can be found in the MOD file or in the soma directory as shown above. You don't need to set up all of these variables - you only need time and current. However, it can be nice to be able to visually check your stimuli. A good check that everything is working properly on the simulation end is to monitor whether the voltage at the soma object (soma(0.5)._ref_v) is the same as the voltage reported by your channel object (NMDAR._ref_Vm).

# %%
#Set up recording vectors for simulation variables
time = h.Vector()
time.record(h._ref_t)

#Set up recording vectors for section variables
vm = h.Vector()
vm.record(soma(0.5)._ref_v)

#Set up recording vectors for mechanism variables
vsyn = h.Vector()
vsyn.record(NMDAR._ref_Vm)

im = h.Vector()
im.record(NMDAR._ref_Inmda)

A = h.Vector() # agonist
A.record(NMDAR._ref_A)

M = h.Vector() # not needed for this simulation, since we aren't using memantine
M.record(NMDAR._ref_M)

fs = 2   # sampling frequency in kHz

# %% [markdown]
# # Create your stimulus
# We need a method for applying agonist and antagonist to our cell. Here we model an increase in agonist/antagonist concentration using a logistic function.

# %%
# Define function used for building vectors to play into NEURON
def logistic(x, xhalf, k, min, max):
    """
    Returns a logistic curve y(x), with a midpoint of xhalf, and a slope of k
    y(x) = (max - min) / (1 + e^(-k(x - xhalf))) + min
    
    Parameters:
    -----------
    x: sequence array
        The x index array for time of which the curve should occur
    xhalf: int, float
        The value in terms of x that signifies the midpoint of x
    k: int, float
        The steepness or rate of increase of the sigmoid function
    min: int, float
        Minimum asymptote of the logistic function
    max: int, float
        Maximum asymptote of the logistic function

    Returns:
    --------
    y: array
        The y-values of len(x) of the logistic function
    """
    y = min + (max - min) / (1 + np.exp(-k * (x - xhalf)))
    return y

# Example parameters
x0 = 120 # Midpoint of the logistic function
fs = 2  # Sampling frequency in Hz
rise_time_10_90 = 150  # 10-90% rise time in ms

# Calculate the slope (k) for the logistic function
k = np.log(9) / (rise_time_10_90/2)

# %% [markdown]
# Create arrays that match your barrel protocol. The arrays are created from three parts, termed slices:

# %%
# create array for protocol and define [agonist]
Glu = np.zeros(152220*fs)
gconc = 1000

# #shorter glu app
# Glu = np.zeros(4000*fs)
# gconc = 1000

# First slice defines the increase in [agonist]
GluOnx = np.arange(0, 1000*fs)
GluOny = logistic(GluOnx, x0 * fs, k, min=0, max=gconc)
Glu[1010*fs:2010*fs] = GluOny

# Second slice defines steady state [agonist]
Glu[2010*fs:150000*fs] = gconc

# #shorter
# Glu[2010*fs:5000*fs] = gconc

# Third slice defines decrease in [agonist]
GluOffx = np.arange(0, 1000*fs)
GluOffy = logistic(GluOffx, x0 * fs, -k, min=0, max=gconc)
Glu[149500*fs:150500*fs] = GluOffy

# Plot
timestep = 1 / fs  # Time step between samples
agtime = np.arange(len(Glu)) * timestep

plt.figure(figsize=(10, 6))
plt.plot(agtime, Glu)
plt.xlabel("Time (ms)")
plt.ylabel("Glu (μM)")  # Modify the units accordingly
plt.title("Agonist")
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(agtime, Glu)
plt.xlabel("Time (ms)")
plt.ylabel("Glu (μM)")  # Modify the units accordingly
plt.title("Agonist")
plt.xlim(990, 1200)
# plt.ylim(0, 100)
plt.grid(True)
plt.show()

# %%
Mem = np.zeros(152220*fs)
mconc1 = 0.1
mconc2 = 0.5
mconc3 = 2
mconc4 = 10
mconc5 = 50

MemOnx1 = np.arange(0,500*fs)
MemOny1 = logistic(MemOnx1, x0 * fs, k, max=mconc1, min=0)
Mem[20500*fs:21000*fs] = MemOny1
Mem[21000*fs:30500*fs] = mconc1

MemOnx2 = np.arange(0,500*fs)
MemOny2 = logistic(MemOnx2, x0 * fs, k, max=mconc2, min=mconc1)
Mem[30500*fs:31000*fs] = MemOny2
Mem[31000*fs:40500*fs] = mconc2

MemOnx3 = np.arange(0,500*fs)
MemOny3 = logistic(MemOnx3, x0 * fs, k, max=mconc3, min=mconc2)
Mem[40500*fs:41000*fs] = MemOny3
Mem[41000*fs:50500*fs] = mconc3

MemOnx4 = np.arange(0,500*fs)
MemOny4 = logistic(MemOnx4, x0 * fs, k, max=mconc4, min=mconc3)
Mem[50500*fs:51000*fs] = MemOny4
Mem[51000*fs:60500*fs] = mconc4

MemOnx5 = np.arange(0,500*fs)
MemOny5 = logistic(MemOnx5, x0 * fs, k, max=mconc5, min=mconc4)
Mem[60500*fs:61000*fs] = MemOny5
Mem[61000*fs:70500*fs] = mconc5

MemOffx = np.arange(0,500*fs)
MemOffy = logistic(MemOffx, x0 * fs, -k, max=mconc5, min=0)
Mem[70500*fs:71000*fs] = MemOffy

plt.figure(figsize=(10, 6))
plt.plot(agtime, Mem)
plt.xlabel("Time (ms)")
plt.ylabel("Mem (μM)")  # Modify the units accordingly
plt.title("Antagonist")
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(agtime, Mem)
plt.xlabel("Time (ms)")
plt.ylabel("Mem (μM)")  # Modify the units accordingly
plt.title("Antagonist")
plt.xlim(30000, 32000)
plt.ylim(0, 1)
plt.grid(True)
plt.show()

# %% [markdown]
# Now we "play" the arrays into NEURON vectors (think play as in playing a movie"). I don't like the terminology but that's what they chose.

# %%
# Create vector from array and play into the mechanism
GluProtocol = h.Vector(Glu)
GluProtocol.play(NMDAR._ref_A, 0.5)

#remove if looking only at peak
MemProtocol = h.Vector(Mem)
MemProtocol.play(NMDAR._ref_M, 0.5)
# Out:
# Vector[10]

# %% [markdown]
# # Set your simulation parameters, run the simulation, and plot the results

# %%
# simulation parameters
h.tstop = 152220 # ms, simulation duration
h.steps_per_ms = 2
h.dt = 0.5
h.celsius = 23

# You can quickly modify your model parameters (rate constants, N, [Ca], etc.) as shown below. Helpful for quickly testing different parameter values 
# without modifying the original MOD FILE, and for hand-fitting your initial simulation.

NMDAR.Ca = 10

NMDAR.kCa1 = 1000
NMDAR.kCa0 = 82
NMDAR.ka1 = .005
NMDAR.ka0 = .025
NMDAR.kg1 =.071
NMDAR.kg0 = .305
NMDAR.kcdd1 = 0.000736532
NMDAR.kcdd0 = 0.000692255
NMDAR.kd1 = 0.00013547
NMDAR.kd0 = 0.000243109
NMDAR.k1M = .03
NMDAR.k0M = 0.143019
NMDAR.ka1M = .005
NMDAR.ka0M = .025
NMDAR.kg1M = .071
NMDAR.kg0M = .305
NMDAR.kcdd1M = 0.06424
NMDAR.kcdd0M = 0.0006
NMDAR.kd1M = 0.000519507
NMDAR.kd0M = 0.000243109
NMDAR.nrecepts = 3.4999

#EN added, from this sheet
#NMDAR.kcdd1M = 0.015392666
#NMDAR.kcdd0M = 1.00E-05
#NMDAR.k0M = 0.461298458

# Run the NEURON simulation
h.run()


# plt.figure(figsize=(10, 6))
# plt.plot(time, im)
# plt.xlabel("Time (ms)")
# plt.ylabel("Current (pA)")  # Modify the units accordingly
# plt.title("SimTrace")
# plt.grid(True)
# plt.show()

# # Can plot the experimental data too, for a visual comparison
# plt.figure(figsize=(10, 6))
# plt.plot(expt, expi)
# plt.xlabel('Time')
# plt.ylabel('Current (pA)')
# plt.title("Experimental Trace")
# plt.grid(True)
# plt.show()

# Plot together if you want a better visual comparision
plt.figure(figsize=(10, 6))
# Plot the first dataset in black
#change if looking at peak only 
plt.plot(expt, expi, color='blue', label='Experimental Trace')
# Plot the second dataset in blue
plt.plot(time, im, color='red', label='SimTrace')
plt.xlabel('Time (ms)')
plt.ylabel('Current (au)')  # Ensure units are consistent for both datasets
plt.title("Comparison of Sim and Exp")
plt.grid(True)
#plt.xlim(1000, 1020)
plt.legend()

plt.show()

# Plot together if you want a better visual comparision
plt.figure(figsize=(10, 6))
# Plot the first dataset in black
plt.plot(expt, expi, color='blue', label='Experimental Trace')
# Plot the second dataset in blue
plt.plot(time, im, color='red', label='SimTrace')
plt.xlabel('Time (ms)')
plt.ylabel('Current (au)')  # Ensure units are consistent for both datasets
plt.title("Comparison of Sim and Exp")
plt.grid(True)
plt.legend()
plt.xlim(40000, 60000)

plt.show()

# %% [markdown]
# # The below step is not necessary for fitting,
# but generally makes doing array manipulations for plotting easier. Can skip if you want. All it does is add or remove values to/from the end baseline region of the experimental trace to ensure it is the exact same number of points as the simulation trace.

# %%
# Convert simulation values to arrays and check that lengths of sim and exp data match
simt = np.array(time)
simi = np.array(im)

print("simi:", len(simi))
print("expi", len(expi))
# Out:
# simi: 304441
# expi 304328

# %%
# Make the lengths match if they don't
# For expt, add the next three sequential time steps
time_step = expt[-1] - expt[-2]

while len(expt) < len(simt):
    expt = np.append(expt, expt[-1] + time_step)
    
print("expt:", len(expt))
print(expt[-5:]) #check that we added the appropriate values

# For expi, just add the final value (i.e. a baseline value) 
while len(expi) < len(simi):
    expi = np.append(expi, expi[-1])
    
print("expi:", len(expi))
print(expi[-5:]) #check that we added the appropriate values
# Out:
# expt: 304441
# [150479.59164308 150480.12231304 150480.65298299 150481.18365295
#  150481.7143229 ]
# expi: 304441
# [-0.04321968 -0.04321968 -0.04321968 -0.04321968 -0.04321968]

# %% [markdown]
# # Time to fit!

# %% [markdown]
# First we create a Multiple Run Fitter (mrf), neuron's built-in fitting tool. We then create a generator within the mrf (think of the mrf as a folder, and a generator as a subfolder) then fill the generator with experimental data and the simulation data before setting up our fit.

# %%
# Create NEURON Vectors and fill with experimental data, for later fitting.
expt_vec = h.Vector(expt)
expi_vec = h.Vector(expi)

# #changed for peak fitting 
# expt_vec = h.Vector(time_peak)
# expi_vec = h.Vector(current_peak)

# %%
# Create a Multiple Run Fitter
mrf = h.MulRunFitter()
mrf.p.pf.title = "MemCaPlanesFit10"
mrf.p.mulfit.title = "MemCaPlanesFit10"

# %%
# Add generator
mrf.p.addgen(0)
gen0 = mrf.p.pf.generatorlist.object(0)
mrf.p.usepanel()
# Out:
# 0.0

# %%
# Turn on generator
gen0.toggle()
# Out:
# 0.0

# %% [markdown]
# Set up your fitness measure, i.e. the method with which the simulation will be fit to data. We are using principal axis reduction.

# %%
# Add a fitness measure
fitness_measure = h.RegionFitness()

# Specify the variable from the simulation for fitting
gen0.gen.add('CaPlaneNMDARwMem[0].Inmda', fitness_measure)

# Set the data to be fit to
fitness_measure.set_data(expt_vec, expi_vec) #defined earlier, but loaded here
# Out:
# 0.0

# %% [markdown]
# Display and test your generator, i.e. the object that contains your simulation and experimental data.

# %%
# Display generator so you can watch your fit progress.
mrf.p.gmode = 1
mrf.p.gmodestr = "Display"
mrf.p.gensel(0, 1)
# Out:
# 0.0

# %%
# Test the run fitness generator
error_value_init = gen0.gen.efun() 

# Print the error value
print("Fitness Error Value:", error_value_init)

plt.figure(figsize=(10, 6))
plt.plot(expt, expi, color='blue', label='Experimental Trace')
plt.plot(time, im, color='red', label='SimTrace')
plt.xlabel('Time (ms)')
plt.ylabel('Current (pA)')  # Ensure units are consistent for both datasets
plt.title("Comparison of Sim and Exp")
plt.grid(False)
plt.legend()

plt.show()
# Out:
# Fitness Error Value: 0.040308534191117996

# %% [markdown]
# # Manage the parameters for your simulation/fit
# The following cells designate your parameters, set their initial values, and allow you to choose which are fixed or free:

# %%
# Append parameters
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kCa1"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kCa0"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].ka1"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].ka0"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kg1"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kg0"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kcdd1"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kcdd0"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kd1"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kd0"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].k1M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].k0M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].ka1M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].ka0M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kg1M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kg0M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kcdd1M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kcdd0M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kd1M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].kd0M"))
mrf.p.pf.parmlist.append(h.RunFitParm("CaPlaneNMDARwMem[0].nrecepts"))
# Out:
# 21.0

# %%
# Set parameter values with kCa0
# : Transition b/t planes
#     kCa1 = 1e-3         (uM-1 s-1)    :Ca "binding"
mrf.p.pf.parmlist.object(0).val = 1000
#     kCa0 = 0.75e-3      (ms-1)        :Ca "unbinding"
mrf.p.pf.parmlist.object(1).val = 82

# :Unblocked Arm
#     ka1 = 31.6           (uM-1 s-1)   :Agonist binding
mrf.p.pf.parmlist.object(2).val = .005
#     ka0 = 1010e-3        (ms-1)       :Agonist unbinding
mrf.p.pf.parmlist.object(3).val = 0.025


# :  Gating 
#     kg1 = 4772.41e-3     (ms-1)       :opening
mrf.p.pf.parmlist.object(4).val = 0.071
#     kg0 = 557e-3         (ms-1)       :closing
mrf.p.pf.parmlist.object(5).val = 0.305

# :  Desensitization
#     kcdd1 = 32.12e-3     (ms-1)       :into Ca-dependent desen
mrf.p.pf.parmlist.object(6).val = 0.000736532

#     kcdd0 = 2.92e-3      (ms-1)       :out of CDD
mrf.p.pf.parmlist.object(7).val = 0.000692255
#     kd1 = 0.66e-3        (ms-1)       :into desens
mrf.p.pf.parmlist.object(8).val = 0.00013547
#     kd0 = 0.05e-3        (ms-1)       :out of desens
mrf.p.pf.parmlist.object(9).val = 0.000243109


# :Blocked Arm
#     k1M = 30              (uM-1 s-1)  :Block rate
mrf.p.pf.parmlist.object(10).val = 0.03
#     k0M = 24e-3           (ms-1)      :Unblock rate
mrf.p.pf.parmlist.object(11).val = 0.143019
#     ka1M = 31.6           (uM-1 s-1)  :Agonist binding
mrf.p.pf.parmlist.object(12).val = .005
#     ka0M = 1010e-3        (ms-1)      :Agonist unbinding
mrf.p.pf.parmlist.object(13).val = 0.025

# :  Gating                                                
#     kg1M = 4772.41e-3     (ms-1)      :opening
mrf.p.pf.parmlist.object(14).val = 0.071
#     kg0M = 53.017e-3      (ms-1)      :closing 
mrf.p.pf.parmlist.object(15).val = 0.30500

# :  Desensitization
#     kcdd1M = 64.24e-3     (ms-1)      :into Ca-dependent desen
mrf.p.pf.parmlist.object(16).val = 0.06424
#     kcdd0M = 0.6e-3       (ms-1)      :out of CDD
mrf.p.pf.parmlist.object(17).val = 0.0006
#     kd1M = 0.54e-3        (ms-1)      :into desens
mrf.p.pf.parmlist.object(18).val = 0.000519507
#     kd0M = 0.0125e-3      (ms-1)      :out of desens
mrf.p.pf.parmlist.object(19).val = 0.000243109

# :  Other params
#     nrecepts = 0.5     arbitrary due to normalization (I/I)     
mrf.p.pf.parmlist.object(20).val = 3.4999

# %%
#Shows that params have been added to parmlist.

print(mrf.p.pf.parmlist.o(0).name, mrf.p.pf.parmlist.o(0).val) 
print(mrf.p.pf.parmlist.o(20).name, mrf.p.pf.parmlist.o(20).val)
# Out:
# CaPlaneNMDARwMem[0].kCa1 1000.0
# CaPlaneNMDARwMem[0].nrecepts 3.4999

# %%
# Display parameter panel in NEURON, makes it easier to follow if you can just see it
mrf.p.showargs()
# Out:
# 0.0

# %%
# Toggle variables. 0 = fixed, 1 = free

# kCa1
mrf.p.pf.parmlist.o(0).doarg = 0
# kCa0
mrf.p.pf.parmlist.o(1).doarg = 0
# ka1
mrf.p.pf.parmlist.o(2).doarg = 0
# ka0 
mrf.p.pf.parmlist.o(3).doarg = 0
# kg1 
mrf.p.pf.parmlist.o(4).doarg = 0
# kg0 
mrf.p.pf.parmlist.o(5).doarg = 0
# kcdd1
mrf.p.pf.parmlist.o(6).doarg = 0
# kcdd0 
mrf.p.pf.parmlist.o(7).doarg = 0
# kd1 
mrf.p.pf.parmlist.o(8).doarg = 0
# kd0 
mrf.p.pf.parmlist.o(9).doarg = 0
# k1M 
mrf.p.pf.parmlist.o(10).doarg = 0
# k0M 
mrf.p.pf.parmlist.o(11).doarg = 0
# ka1M 
mrf.p.pf.parmlist.o(12).doarg = 0
# ka0M 
mrf.p.pf.parmlist.o(13).doarg = 0
# kg1M 
mrf.p.pf.parmlist.o(14).doarg = 0
# kg0M 
mrf.p.pf.parmlist.o(15).doarg = 0
# kcdd1M
mrf.p.pf.parmlist.o(16).doarg = 1
# kcdd0M 
mrf.p.pf.parmlist.o(17).doarg = 1
# kd1M
mrf.p.pf.parmlist.o(18).doarg = 0
# kd0M 
mrf.p.pf.parmlist.o(19).doarg = 0
# nrecepts
mrf.p.pf.parmlist.o(20).doarg = 1

mrf.p.pf.def_parmlist_use()
# Out:
# 0.0

# %%
# Step 5C: Constrain parameters
mrf.p.showdomain()
mrf.p.uselog(1)
mrf.p.limits(1e-5, 1e5)
# Out:
# 0.0

# %% [markdown]
# # Manage your optimization settings:

# %%
# Choose and use optimizer
mrf.opt.set_optimizer(h.mulfit_optimizers_[0].s)
mrf.p.mulfit.showopt()

# Change "# of quad forms before return"
mrf.opt.optimizer.nstep = 1

# %% [markdown]
# # Run the fit

# %%
#NEW AS OF REVIEWS ===== Multi-run fitting with saved params + traces =====
N_RUNS = 10
N_PRUN_PER_RUN = 5  # inner optimizer iterations

# --- grab parameter metadata from the parmlist you already built ---
n_parms = int(mrf.p.pf.parmlist.count())
parm_names = [mrf.p.pf.parmlist.object(i).name for i in range(n_parms)]

# store initial vals so each run starts from same point
init_vals = np.array([mrf.p.pf.parmlist.object(i).val for i in range(n_parms)], dtype=float)

# identify free parameters (doarg==1) if you set them; else this is empty
free_idx = []
for i in range(n_parms):
    try:
        if int(mrf.p.pf.parmlist.object(i).doarg) == 1:
            free_idx.append(i)
    except Exception:
        pass
free_idx = np.array(free_idx, dtype=int)

all_params = []
all_traces = []
all_errors = []

# Set lognormal jitter for positive rate constants
jitterfactor = 1.2

for run_i in range(N_RUNS):
    print(f"\n=== FIT RUN {run_i+1}/{N_RUNS} ===")

    # --- reset params to initial values ---
    for j in range(n_parms):
        mrf.p.pf.parmlist.object(j).val = float(init_vals[j])

    # --- add  jitter to FREE params to encourage run-to-run variation ---
    # (if  optimizer is deterministic, this is what makes CI meaningful)
    if free_idx.size > 0:
        for j in free_idx:
            v = float(mrf.p.pf.parmlist.object(j).val)
            if v > 0:
                mrf.p.pf.parmlist.object(j).val = v * np.exp(np.random.normal(0, jitterfactor))
            else:
                # tiny normal jitter for zero/negative values
                mrf.p.pf.parmlist.object(j).val = v + np.random.normal(0, 1e-6)

    # --- run the optimizer ---
    for _ in range(N_PRUN_PER_RUN):
        mrf.prun()

    # --- capture params + trace + error ---
    fitted_vals = np.array([mrf.p.pf.parmlist.object(j).val for j in range(n_parms)], dtype=float)
    sim_trace = np.array(im, dtype=float)   # uses your existing 'im'
    err_val = float(gen0.gen.efun())

    all_params.append(fitted_vals)
    all_traces.append(sim_trace)
    all_errors.append(err_val)

    # --- save each run individually ---
    run_df = pd.DataFrame({"Parameter": parm_names, "value": fitted_vals})
    run_df.to_csv(f"optparams_run{run_i+1}.csv", index=False)
    np.save(f"simiopt_run{run_i+1}.npy", sim_trace)

    print("Run error:", err_val)

# convert to arrays for later cells
all_params = np.vstack(all_params)   # shape (N_RUNS, n_parms)
all_traces = np.vstack(all_traces)   # shape (N_RUNS, n_timepoints)
all_errors = np.array(all_errors)

print("\nFinished multi-run fitting.")
print("all_params shape:", all_params.shape)
print("all_traces shape:", all_traces.shape)
print("errors:", all_errors)
# Out:
# === FIT RUN 1/10 ===
# nquad=0 nefun=1 time=0 e=5.6598332
# nquad=1 nefun=27 time=27 e=0.137882
# nquad=0 nefun=1 time=0 e=0.137882
# nquad=1 nefun=24 time=24 e=0.060361668
# nquad=0 nefun=1 time=0 e=0.060361668
# nquad=1 nefun=24 time=23 e=0.011083646
# nquad=0 nefun=1 time=0 e=0.011083646
# nquad=1 nefun=24 time=24 e=0.0099285196
# nquad=0 nefun=1 time=0 e=0.0099285196
# nquad=1 nefun=24 time=27 e=0.0098899096
# Run error: 0.009889909587373793
#
# === FIT RUN 2/10 ===
# nquad=0 nefun=1 time=0 e=2.3648026
# nquad=1 nefun=27 time=32 e=0.081212953
# nquad=0 nefun=1 time=0 e=0.081212953
# nquad=1 nefun=24 time=27 e=0.023625879
# nquad=0 nefun=1 time=0 e=0.023625879
# nquad=1 nefun=24 time=28 e=0.011160187
# nquad=0 nefun=1 time=0 e=0.011160187
# nquad=1 nefun=24 time=27 e=0.010440213
# nquad=0 nefun=1 time=0 e=0.010440213
# nquad=1 nefun=24 time=27 e=0.0099342989
# Run error: 0.009934298882938564
#
# === FIT RUN 3/10 ===
# nquad=0 nefun=1 time=0 e=2.7929538
# nquad=1 nefun=27 time=32 e=0.085909832
# nquad=0 nefun=1 time=0 e=0.085909832
# nquad=1 nefun=24 time=29 e=0.016982889
# nquad=0 nefun=1 time=0 e=0.016982889
# nquad=1 nefun=24 time=29 e=0.0099503198
# nquad=0 nefun=1 time=0 e=0.0099503198
# nquad=1 nefun=24 time=28 e=0.0098897917
# nquad=0 nefun=1 time=0 e=0.0098897917
# nquad=1 nefun=26 time=31 e=0.0098893252
# Run error: 0.009889325223087848
#
# === FIT RUN 4/10 ===
# nquad=0 nefun=1 time=0 e=0.47173633
# nquad=1 nefun=25 time=30 e=0.028048905
# nquad=0 nefun=1 time=0 e=0.028048905
# nquad=1 nefun=27 time=33 e=0.011544702
# nquad=0 nefun=1 time=0 e=0.011544702
# nquad=1 nefun=27 time=33 e=0.011157957
# nquad=0 nefun=1 time=0 e=0.011157957
# nquad=1 nefun=24 time=30 e=0.010430494
# nquad=0 nefun=1 time=0 e=0.010430494
# nquad=1 nefun=24 time=31 e=0.0099930426
# Run error: 0.009993042573054965
#
# === FIT RUN 5/10 ===
# nquad=0 nefun=1 time=0 e=0.14595
# nquad=1 nefun=24 time=31 e=0.011454359
# nquad=0 nefun=1 time=0 e=0.011454359
# nquad=1 nefun=24 time=32 e=0.010775078
# nquad=0 nefun=1 time=0 e=0.010775078
# nquad=1 nefun=24 time=32 e=0.010214368
# nquad=0 nefun=1 time=0 e=0.010214368
# nquad=1 nefun=24 time=34 e=0.0098968657
# nquad=0 nefun=1 time=0 e=0.0098968657
# nquad=1 nefun=24 time=34 e=0.0098893259
# Run error: 0.009889325940417887
#
# === FIT RUN 6/10 ===
# nquad=0 nefun=1 time=0 e=0.323136
# nquad=1 nefun=24 time=34 e=0.032515859
# nquad=0 nefun=1 time=0 e=0.032515859
# nquad=1 nefun=24 time=34 e=0.011278391
# nquad=0 nefun=1 time=0 e=0.011278391
# nquad=1 nefun=24 time=35 e=0.010624276
# nquad=0 nefun=1 time=0 e=0.010624276
# nquad=1 nefun=24 time=35 e=0.0099949702
# nquad=0 nefun=1 time=0 e=0.0099949702
# nquad=1 nefun=24 time=36 e=0.0098899926
# Run error: 0.009889992588121753
#
# === FIT RUN 7/10 ===
# nquad=0 nefun=1 time=0 e=0.35808864
# nquad=1 nefun=26 time=39 e=0.010530281
# nquad=0 nefun=1 time=0 e=0.010530281
# nquad=1 nefun=24 time=39 e=0.0099526078
# nquad=0 nefun=1 time=0 e=0.0099526078
# nquad=1 nefun=24 time=37 e=0.0098895074
# nquad=0 nefun=1 time=0 e=0.0098895074
# nquad=1 nefun=26 time=42 e=0.0098893252
# nquad=0 nefun=1 time=0 e=0.0098893252
# nquad=1 nefun=53 time=88 e=0.0098893252
# Run error: 0.009889325174376082
#
# === FIT RUN 8/10 ===
# nquad=0 nefun=1 time=0 e=0.17177448
# nquad=1 nefun=31 time=55 e=0.044620181
# nquad=0 nefun=1 time=0 e=0.044620181
# nquad=1 nefun=24 time=41 e=0.0105147
# nquad=0 nefun=1 time=0 e=0.0105147
# nquad=1 nefun=24 time=41 e=0.0099386894
# nquad=0 nefun=1 time=0 e=0.0099386894
# nquad=1 nefun=24 time=41 e=0.0098893855
# nquad=0 nefun=1 time=0 e=0.0098893855
# nquad=1 nefun=26 time=45 e=0.0098893252
# Run error: 0.009889325174358088
#
# === FIT RUN 9/10 ===
# nquad=0 nefun=1 time=0 e=0.50324347
# nquad=1 nefun=25 time=45 e=0.021248158
# nquad=0 nefun=1 time=0 e=0.021248158
# nquad=1 nefun=24 time=45 e=0.011280843
# nquad=0 nefun=1 time=0 e=0.011280843
# nquad=1 nefun=24 time=46 e=0.010877369
# nquad=0 nefun=1 time=0 e=0.010877369
# nquad=1 nefun=24 time=47 e=0.010372063
# nquad=0 nefun=1 time=0 e=0.010372063
# nquad=1 nefun=24 time=48 e=0.0099952108
# Run error: 0.00999521081859966
#
# === FIT RUN 10/10 ===
# nquad=0 nefun=1 time=0 e=0.34746013
# nquad=1 nefun=25 time=53 e=0.012163895
# nquad=0 nefun=1 time=0 e=0.012163895
# nquad=1 nefun=24 time=44 e=0.01064232
# nquad=0 nefun=1 time=0 e=0.01064232
# nquad=1 nefun=24 time=44 e=0.010015964
# nquad=0 nefun=1 time=0 e=0.010015964
# nquad=1 nefun=24 time=44 e=0.0098896762
# nquad=0 nefun=1 time=0 e=0.0098896762
# nquad=1 nefun=26 time=50 e=0.0098893252
# Run error: 0.009889325205881311
#
# Finished multi-run fitting.
# all_params shape: (10, 21)
# all_traces shape: (10, 304441)
# errors: [0.00988991 0.0099343  0.00988933 0.00999304 0.00988933 0.00988999
#  0.00988933 0.00988933 0.00999521 0.00988933]

# %%
# # Run optimizer
# for _ in range(5):
#     mrf.prun()
    
# plt.figure(figsize=(10, 6))
# #change if looking at peak
# plt.plot(expt, expi, color='blue', label='Experimental Trace')
# plt.plot(time, im, color='red', label='SimTrace')
# plt.xlabel('Time (ms)')
# plt.ylabel('Current (pA)')  # Ensure units are consistent for both datasets
# plt.title("Comparison of Sim and Exp")
# plt.grid(False)
# plt.legend()

# plt.show()

# error_value_final0 = gen0.gen.efun()
# # Print the error value
# print("Fitness Error Value:", error_value_final0)

# kD = (mrf.p.pf.parmlist.object(0).val/mrf.p.pf.parmlist.object(1).val)
# # Print the kD value
# print("kD:", kD)
# Out:
# nquad=0 nefun=1 time=0 e=0.0093185647
# nquad=1 nefun=26 time=27 e=0.0092934253
# nquad=0 nefun=1 time=0 e=0.0092934253
# nquad=1 nefun=26 time=27 e=0.0092934236
# nquad=0 nefun=1 time=0 e=0.0092934236
# nquad=1 nefun=47 time=52 e=0.0092934236
# nquad=0 nefun=1 time=0 e=0.0092934236
# nquad=1 nefun=45 time=53 e=0.0092934236
# nquad=0 nefun=1 time=0 e=0.0092934236
# nquad=1 nefun=49 time=59 e=0.0092934236
# Fitness Error Value: 0.009293423623896391
# kD: 12.195121951219512

# %% [markdown]
# If you want to inspect/adjust the figure without waiting for the fit to run again, just uncomment the cell below:

# %%
# plt.figure(figsize=(10, 6))
# plt.plot(expt, expi, color='blue', label='Experimental Trace')
# plt.plot(time, im, color='red', label='SimTrace')
# plt.xlabel('Time (ms)')
# plt.ylabel('Current (pA)')  # Ensure units are consistent for both datasets
# plt.title("Comparison of Sim and Exp")
# plt.grid(False)
# plt.legend()
# # Save the figure with the below line:
# # plt.savefig('OptGluApp10CaAverage.pdf', transparent=True)
# plt.show()

# %%
#making experimental trace a csv
exptrace = {'time': expt, 'exp trace': expi}
df = pd.DataFrame(exptrace)
df.to_csv('10CaMem', index = False)

#making modeled trace a csv
simtrace = {'time': time, 'sim trace': im}
df2 = pd.DataFrame(simtrace)
df2.to_csv('sim10CaMem', index = False)

#making a collated csv to contain both experimental and simulated trace
collated_df = pd.merge(df, df2, on = 'time', how = 'outer')
collated_df.to_csv('10CaMem.csv', index = False)

# %% [markdown]
# Make a table for exporting values:

# %%
# NEW AS OF REVIEWS
N_RUNS = all_params.shape[0]
n_parms = all_params.shape[1]

# parameter names from parmlist (same order as all_params)
parm_names = [mrf.p.pf.parmlist.object(i).name for i in range(n_parms)]

mean_params = all_params.mean(axis=0)

# standard error; handle N_RUNS==1 safely
if N_RUNS > 1:
    se_params = all_params.std(axis=0, ddof=1) / np.sqrt(N_RUNS)
else:
    se_params = np.full_like(mean_params, np.nan)

# t critical for 95% CI
from scipy.stats import t as student_t
tcrit = float(student_t.ppf(0.975, df=N_RUNS-1))

ci_low = mean_params - tcrit * se_params
ci_high = mean_params + tcrit * se_params

# build summary table (ALL params)
param_ci_df = pd.DataFrame({
    "Parameter": parm_names,
    "Mean": mean_params,
    "CI_low_95": ci_low,
    "CI_high_95": ci_high,
})

# include per-run values for transparency
for r in range(N_RUNS):
    param_ci_df[f"Run{r+1}"] = all_params[r]

param_ci_df.to_csv("optparams_CI10Mem.csv", index=False)

# ---------- FREE-PARAMS-ONLY table ----------
free_idx = []
for i in range(n_parms):
    try:
        if int(mrf.p.pf.parmlist.object(i).doarg) == 1:
            free_idx.append(i)
    except Exception:
        pass
free_idx = np.array(free_idx, dtype=int)

param_ci_free_df = param_ci_df.iloc[free_idx].reset_index(drop=True)
param_ci_free_df.to_csv("optparams_CI10Mem_FREEONLY.csv", index=False)

print(f"Free parameters detected: {len(free_idx)} / {n_parms}")

# ---------- STYLING (for display only) ----------
# columns to format numerically
num_cols = [c for c in param_ci_df.columns if c != "Parameter"]

def _style_ci_table(df, title=""):
    return (df.style
            .set_caption(title)
            .format({c: "{:.6g}" for c in num_cols})  # compact scientific/float formatting
            .set_properties(**{
                "text-align": "center",
                "font-size": "12pt",
                "border": "1px solid #ccc",
                "padding": "4px"
            })
            .set_table_styles([
                {"selector": "caption",
                 "props": [("caption-side", "top"),
                           ("font-weight", "bold"),
                           ("font-size", "14pt"),
                           ("padding", "6px")]},
                {"selector": "th",
                 "props": [("background-color", "#f2f2f2"),
                           ("font-weight", "bold"),
                           ("border", "1px solid #ccc")]},
                {"selector": "tr:nth-child(even)",
                 "props": [("background-color", "#fafafa")]}
            ])
           )

from IPython.display import display

param_ci_df_style = _style_ci_table(param_ci_df, "All Parameters (Mean ± 95% CI)")
param_ci_free_df_style = _style_ci_table(param_ci_free_df, "Free / Optimized Parameters Only (Mean ± 95% CI)")

display(param_ci_df_style)
display(param_ci_free_df_style)
# Out:
# Free parameters detected: 3 / 21
# <style  type="text/css" >
#     #T_b7700_ caption {
#           caption-side: top;
#           font-weight: bold;
#           font-size: 14pt;
#           padding: 6px;
#     }    #T_b7700_ th {
#           background-color: #f2f2f2;
#           font-weight: bold;
#           border: 1px solid #ccc;
#     }    #T_b7700_ tr:nth-child(even) {
#           background-color: #fafafa;
#     }#T_b7700_row0_col0,#T_b7700_row0_col1,#T_b7700_row0_col2,#T_b7700_row0_col3,#T_b7700_row0_col4,#T_b7700_row0_col5,#T_b7700_row0_col6,#T_b7700_row0_col7,#T_b7700_row0_col8,#T_b7700_row0_col9,#T_b7700_row0_col10,#T_b7700_row0_col11,#T_b7700_row0_col12,#T_b7700_row0_col13,#T_b7700_row1_col0,#T_b7700_row1_col1,#T_b7700_row1_col2,#T_b7700_row1_col3,#T_b7700_row1_col4,#T_b7700_row1_col5,#T_b7700_row1_col6,#T_b7700_row1_col7,#T_b7700_row1_col8,#T_b7700_row1_col9,#T_b7700_row1_col10,#T_b7700_row1_col11,#T_b7700_row1_col12,#T_b7700_row1_col13,#T_b7700_row2_col0,#T_b7700_row2_col1,#T_b7700_row2_col2,#T_b7700_row2_col3,#T_b7700_row2_col4,#T_b7700_row2_col5,#T_b7700_row2_col6,#T_b7700_row2_col7,#T_b7700_row2_col8,#T_b7700_row2_col9,#T_b7700_row2_col10,#T_b7700_row2_col11,#T_b7700_row2_col12,#T_b7700_row2_col13,#T_b7700_row3_col0,#T_b7700_row3_col1,#T_b7700_row3_col2,#T_b7700_row3_col3,#T_b7700_row3_col4,#T_b7700_row3_col5,#T_b7700_row3_col6,#T_b7700_row3_col7,#T_b7700_row3_col8,#T_b7700_row3_col9,#T_b7700_row3_col10,#T_b7700_row3_col11,#T_b7700_row3_col12,#T_b7700_row3_col13,#T_b7700_row4_col0,#T_b7700_row4_col1,#T_b7700_row4_col2,#T_b7700_row4_col3,#T_b7700_row4_col4,#T_b7700_row4_col5,#T_b7700_row4_col6,#T_b7700_row4_col7,#T_b7700_row4_col8,#T_b7700_row4_col9,#T_b7700_row4_col10,#T_b7700_row4_col11,#T_b7700_row4_col12,#T_b7700_row4_col13,#T_b7700_row5_col0,#T_b7700_row5_col1,#T_b7700_row5_col2,#T_b7700_row5_col3,#T_b7700_row5_col4,#T_b7700_row5_col5,#T_b7700_row5_col6,#T_b7700_row5_col7,#T_b7700_row5_col8,#T_b7700_row5_col9,#T_b7700_row5_col10,#T_b7700_row5_col11,#T_b7700_row5_col12,#T_b7700_row5_col13,#T_b7700_row6_col0,#T_b7700_row6_col1,#T_b7700_row6_col2,#T_b7700_row6_col3,#T_b7700_row6_col4,#T_b7700_row6_col5,#T_b7700_row6_col6,#T_b7700_row6_col7,#T_b7700_row6_col8,#T_b7700_row6_col9,#T_b7700_row6_col10,#T_b7700_row6_col11,#T_b7700_row6_col12,#T_b7700_row6_col13,#T_b7700_row7_col0,#T_b7700_row7_col1,#T_b7700_row7_col2,#T_b7700_row7_col3,#T_b7700_row7_col4,#T_b7700_row7_col5,#T_b7700_row7_col6,#T_b7700_row7_col7,#T_b7700_row7_col8,#T_b7700_row7_col9,#T_b7700_row7_col10,#T_b7700_row7_col11,#T_b7700_row7_col12,#T_b7700_row7_col13,#T_b7700_row8_col0,#T_b7700_row8_col1,#T_b7700_row8_col2,#T_b7700_row8_col3,#T_b7700_row8_col4,#T_b7700_row8_col5,#T_b7700_row8_col6,#T_b7700_row8_col7,#T_b7700_row8_col8,#T_b7700_row8_col9,#T_b7700_row8_col10,#T_b7700_row8_col11,#T_b7700_row8_col12,#T_b7700_row8_col13,#T_b7700_row9_col0,#T_b7700_row9_col1,#T_b7700_row9_col2,#T_b7700_row9_col3,#T_b7700_row9_col4,#T_b7700_row9_col5,#T_b7700_row9_col6,#T_b7700_row9_col7,#T_b7700_row9_col8,#T_b7700_row9_col9,#T_b7700_row9_col10,#T_b7700_row9_col11,#T_b7700_row9_col12,#T_b7700_row9_col13,#T_b7700_row10_col0,#T_b7700_row10_col1,#T_b7700_row10_col2,#T_b7700_row10_col3,#T_b7700_row10_col4,#T_b7700_row10_col5,#T_b7700_row10_col6,#T_b7700_row10_col7,#T_b7700_row10_col8,#T_b7700_row10_col9,#T_b7700_row10_col10,#T_b7700_row10_col11,#T_b7700_row10_col12,#T_b7700_row10_col13,#T_b7700_row11_col0,#T_b7700_row11_col1,#T_b7700_row11_col2,#T_b7700_row11_col3,#T_b7700_row11_col4,#T_b7700_row11_col5,#T_b7700_row11_col6,#T_b7700_row11_col7,#T_b7700_row11_col8,#T_b7700_row11_col9,#T_b7700_row11_col10,#T_b7700_row11_col11,#T_b7700_row11_col12,#T_b7700_row11_col13,#T_b7700_row12_col0,#T_b7700_row12_col1,#T_b7700_row12_col2,#T_b7700_row12_col3,#T_b7700_row12_col4,#T_b7700_row12_col5,#T_b7700_row12_col6,#T_b7700_row12_col7,#T_b7700_row12_col8,#T_b7700_row12_col9,#T_b7700_row12_col10,#T_b7700_row12_col11,#T_b7700_row12_col12,#T_b7700_row12_col13,#T_b7700_row13_col0,#T_b7700_row13_col1,#T_b7700_row13_col2,#T_b7700_row13_col3,#T_b7700_row13_col4,#T_b7700_row13_col5,#T_b7700_row13_col6,#T_b7700_row13_col7,#T_b7700_row13_col8,#T_b7700_row13_col9,#T_b7700_row13_col10,#T_b7700_row13_col11,#T_b7700_row13_col12,#T_b7700_row13_col13,#T_b7700_row14_col0,#T_b7700_row14_col1,#T_b7700_row14_col2,#T_b7700_row14_col3,#T_b7700_row14_col4,#T_b7700_row14_col5,#T_b7700_row14_col6,#T_b7700_row14_col7 ...
#             text-align:  center;
#             font-size:  12pt;
#             border:  1px solid #ccc;
#             padding:  4px;
#         }</style><table id="T_b7700_" ><caption>All Parameters (Mean ± 95% CI)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Parameter</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >CI_low_95</th>        <th class="col_heading level0 col3" >CI_high_95</th>        <th class="col_heading level0 col4" >Run1</th>        <th class="col_heading level0 col5" >Run2</th>        <th class="col_heading level0 col6" >Run3</th>        <th class="col_heading level0 col7" >Run4</th>        <th class="col_heading level0 col8" >Run5</th>        <th class="col_heading level0 col9" >Run6</th>        <th class="col_heading level0 col10" >Run7</th>        <th class="col_heading level0 col11" >Run8</th>        <th class="col_heading level0 col12" >Run9</th>        <th class="col_heading level0 col13" >Run10</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b7700_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b7700_row0_col0" class="data row0 col0" >CaPlaneNMDARwMem[0].kCa1</td>
#                         <td id="T_b7700_row0_col1" class="data row0 col1" >1000</td>
#                         <td id="T_b7700_row0_col2" class="data row0 col2" >1000</td>
#                         <td id="T_b7700_row0_col3" class="data row0 col3" >1000</td>
#                         <td id="T_b7700_row0_col4" class="data row0 col4" >1000</td>
#                         <td id="T_b7700_row0_col5" class="data row0 col5" >1000</td>
#                         <td id="T_b7700_row0_col6" class="data row0 col6" >1000</td>
# <style  type="text/css" >
#     #T_29f76_ caption {
#           caption-side: top;
#           font-weight: bold;
#           font-size: 14pt;
#           padding: 6px;
#     }    #T_29f76_ th {
#           background-color: #f2f2f2;
#           font-weight: bold;
#           border: 1px solid #ccc;
#     }    #T_29f76_ tr:nth-child(even) {
#           background-color: #fafafa;
#     }#T_29f76_row0_col0,#T_29f76_row0_col1,#T_29f76_row0_col2,#T_29f76_row0_col3,#T_29f76_row0_col4,#T_29f76_row0_col5,#T_29f76_row0_col6,#T_29f76_row0_col7,#T_29f76_row0_col8,#T_29f76_row0_col9,#T_29f76_row0_col10,#T_29f76_row0_col11,#T_29f76_row0_col12,#T_29f76_row0_col13,#T_29f76_row1_col0,#T_29f76_row1_col1,#T_29f76_row1_col2,#T_29f76_row1_col3,#T_29f76_row1_col4,#T_29f76_row1_col5,#T_29f76_row1_col6,#T_29f76_row1_col7,#T_29f76_row1_col8,#T_29f76_row1_col9,#T_29f76_row1_col10,#T_29f76_row1_col11,#T_29f76_row1_col12,#T_29f76_row1_col13,#T_29f76_row2_col0,#T_29f76_row2_col1,#T_29f76_row2_col2,#T_29f76_row2_col3,#T_29f76_row2_col4,#T_29f76_row2_col5,#T_29f76_row2_col6,#T_29f76_row2_col7,#T_29f76_row2_col8,#T_29f76_row2_col9,#T_29f76_row2_col10,#T_29f76_row2_col11,#T_29f76_row2_col12,#T_29f76_row2_col13{
#             text-align:  center;
#             font-size:  12pt;
#             border:  1px solid #ccc;
#             padding:  4px;
#         }</style><table id="T_29f76_" ><caption>Free / Optimized Parameters Only (Mean ± 95% CI)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Parameter</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >CI_low_95</th>        <th class="col_heading level0 col3" >CI_high_95</th>        <th class="col_heading level0 col4" >Run1</th>        <th class="col_heading level0 col5" >Run2</th>        <th class="col_heading level0 col6" >Run3</th>        <th class="col_heading level0 col7" >Run4</th>        <th class="col_heading level0 col8" >Run5</th>        <th class="col_heading level0 col9" >Run6</th>        <th class="col_heading level0 col10" >Run7</th>        <th class="col_heading level0 col11" >Run8</th>        <th class="col_heading level0 col12" >Run9</th>        <th class="col_heading level0 col13" >Run10</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_29f76_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_29f76_row0_col0" class="data row0 col0" >CaPlaneNMDARwMem[0].kcdd1M</td>
#                         <td id="T_29f76_row0_col1" class="data row0 col1" >0.00175084</td>
#                         <td id="T_29f76_row0_col2" class="data row0 col2" >0.00168656</td>
#                         <td id="T_29f76_row0_col3" class="data row0 col3" >0.00181512</td>
#                         <td id="T_29f76_row0_col4" class="data row0 col4" >0.00177678</td>
#                         <td id="T_29f76_row0_col5" class="data row0 col5" >0.00155454</td>
#                         <td id="T_29f76_row0_col6" class="data row0 col6" >0.00174421</td>
#                         <td id="T_29f76_row0_col7" class="data row0 col7" >0.00190372</td>
#                         <td id="T_29f76_row0_col8" class="data row0 col8" >0.00174581</td>
#                         <td id="T_29f76_row0_col9" class="data row0 col9" >0.00170972</td>
#                         <td id="T_29f76_row0_col10" class="data row0 col10" >0.00174401</td>
#                         <td id="T_29f76_row0_col11" class="data row0 col11" >0.00174401</td>
#                         <td id="T_29f76_row0_col12" class="data row0 col12" >0.00184136</td>
#                         <td id="T_29f76_row0_col13" class="data row0 col13" >0.00174424</td>
#             </tr>
#             <tr>
#                         <th id="T_29f76_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_29f76_row1_col0" class="data row1 col0" >CaPlaneNMDARwMem[0].kcdd0M</td>
#                         <td id="T_29f76_row1_col1" class="data row1 col1" >0.000303728</td>
#                         <td id="T_29f76_row1_col2" class="data row1 col2" >0.000278845</td>
#                         <td id="T_29f76_row1_col3" class="data row1 col3" >0.000328611</td>
#                         <td id="T_29f76_row1_col4" class="data row1 col4" >0.00028999</td>
#                         <td id="T_29f76_row1_col5" class="data row1 col5" >0.000274571</td>
#                         <td id="T_29f76_row1_col6" class="data row1 col6" >0.000289306</td>
#                         <td id="T_29f76_row1_col7" class="data row1 col7" >0.000363187</td>
#                         <td id="T_29f76_row1_col8" class="data row1 col8" >0.00028951</td>
#                         <td id="T_29f76_row1_col9" class="data row1 col9" >0.000288069</td>
#                         <td id="T_29f76_row1_col10" class="data row1 col10" >0.000289316</td>
#                         <td id="T_29f76_row1_col11" class="data row1 col11" >0.000289315</td>
#                         <td id="T_29f76_row1_col12" class="data row1 col12" >0.000374695</td>
#                         <td id="T_29f76_row1_col13" class="data row1 col13" >0.000289318</td>
#             </tr>
#             <tr>
#                         <th id="T_29f76_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_29f76_row2_col0" class="data row2 col0" >CaPlaneNMDARwMem[0].nrecepts</td>
#                         <td id="T_29f76_row2_col1" class="data row2 col1" >3.46368</td>
#                         <td id="T_29f76_row2_col2" class="data row2 col2" >3.45119</td>
#                         <td id="T_29f76_row2_col3" class="data row2 col3" >3.47617</td>
#                         <td id="T_29f76_row2_col4" class="data row2 col4" >3.47509</td>
#                         <td id="T_29f76_row2_col5" class="data row2 col5" >3.44698</td>
#                         <td id="T_29f76_row2_col6" class="data row2 col6" >3.47391</td>
#                         <td id="T_29f76_row2_col7" class="data row2 col7" >3.42862</td>
#                         <td id="T_29f76_row2_col8" class="data row2 col8" >3.4739</td>
#                         <td id="T_29f76_row2_col9" class="data row2 col9" >3.4745</td>
#                         <td id="T_29f76_row2_col10" class="data row2 col10" >3.4739</td>
#                         <td id="T_29f76_row2_col11" class="data row2 col11" >3.4739</td>
#                         <td id="T_29f76_row2_col12" class="data row2 col12" >3.44209</td>
#                         <td id="T_29f76_row2_col13" class="data row2 col13" >3.47391</td>
#             </tr>
#     </tbody></table>

# %%
# NEW AS OF REVIEWS
# so it pops out
# %matplotlib qt
plt.ion()

# ===== Mean simulated trace + 95% CI band, aligned to experimental time =====

# --- coerce to 1D numpy arrays ---
time_sim = np.asarray(time).squeeze().astype(float)
expt_ms  = np.asarray(expt).squeeze().astype(float)
expi_pA  = np.asarray(expi).squeeze().astype(float)

all_traces_arr = np.asarray(all_traces)
N_RUNS = all_traces_arr.shape[0]

mean_trace = all_traces_arr.mean(axis=0)

if N_RUNS > 1:
    se_trace = all_traces_arr.std(axis=0, ddof=1) / np.sqrt(N_RUNS)
else:
    se_trace = np.full_like(mean_trace, np.nan)

# t critical

from scipy.stats import t as student_t
tcrit = float(student_t.ppf(0.975, df=N_RUNS-1))

trace_ci_low  = mean_trace - tcrit * se_trace
trace_ci_high = mean_trace + tcrit * se_trace

# --- decide target time base for output/plot ---
# If sim and exp have same length AND similar time vectors -> use sim directly
same_len = (len(time_sim) == len(expt_ms) == len(expi_pA) == len(mean_trace))
same_timebase = False
if same_len:
    # tolerate tiny float differences
    same_timebase = np.allclose(time_sim, expt_ms, rtol=1e-3, atol=1e-3)

if same_timebase:
    time_out = time_sim
    sim_mean_out = mean_trace
    sim_low_out  = trace_ci_low
    sim_high_out = trace_ci_high
else:
    # Interpolate sim stats onto experimental time base
    time_out = expt_ms

    # np.interp requires increasing x
    sort_idx = np.argsort(time_sim)
    t_sorted = time_sim[sort_idx]
    mean_sorted = mean_trace[sort_idx]
    low_sorted  = trace_ci_low[sort_idx]
    high_sorted = trace_ci_high[sort_idx]

    sim_mean_out = np.interp(time_out, t_sorted, mean_sorted)
    sim_low_out  = np.interp(time_out, t_sorted, low_sorted)
    sim_high_out = np.interp(time_out, t_sorted, high_sorted)

# --- save arrays ---
np.save("simiopt_mean.npy", sim_mean_out)
np.save("simiopt_CI_low.npy", sim_low_out)
np.save("simiopt_CI_high.npy", sim_high_out)

# --- save CSV (all columns same length by construction) ---
trace_df = pd.DataFrame({
    "time_ms": time_out,
    "exp_trace": expi_pA,
    "sim_mean": sim_mean_out,
    "sim_CI_low_95": sim_low_out,
    "sim_CI_high_95": sim_high_out,
})
trace_df.to_csv("simtrace_mean_CI10Mem.csv", index=False)

# --- plot ---
plt.figure(figsize=(10,6))

# Experimental trace BEHIND everything
plt.plot(expt_ms, expi_pA, label="Experimental Trace", zorder=1, alpha=0.8)

# CI band ABOVE experimental trace
plt.fill_between(time_out, sim_low_out, sim_high_out,
                 color="red", alpha=0.25, label="Sim 95% CI", zorder=2)

# Mean sim trace ON TOP
plt.plot(time_out, sim_mean_out, label="Mean Sim Trace", zorder=3)

plt.xlabel("Time (ms)")
plt.ylabel("Current (pA)")
plt.title("Experimental vs Mean Simulated Trace (95% CI)")
plt.legend()
plt.grid(False)
plt.show()

print("Lengths:",
      "expt", len(expt_ms),
      "expi", len(expi_pA),
      "sim(time)", len(time_sim),
      "sim(trace)", len(mean_trace))
print("Aligned output length:", len(time_out))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e6af4d0c858b> in <module>
#       2 # so it pops out
#       3 get_ipython().run_line_magic('matplotlib', 'qt')
# ----> 4 plt.ion()
#       5
#       6 # ===== Mean simulated trace + 95% CI band, aligned to experimental time =====
#
# NameError: name 'plt' is not defined

# %%
# paramvalues = (
# mrf.p.pf.parmlist.object(0).val,
# mrf.p.pf.parmlist.object(1).val,
# mrf.p.pf.parmlist.object(2).val,
# mrf.p.pf.parmlist.object(3).val,
# mrf.p.pf.parmlist.object(4).val, 
# mrf.p.pf.parmlist.object(5).val,
# mrf.p.pf.parmlist.object(6).val,
# mrf.p.pf.parmlist.object(7).val,
# mrf.p.pf.parmlist.object(8).val,
# mrf.p.pf.parmlist.object(9).val,
# mrf.p.pf.parmlist.object(10).val,
# mrf.p.pf.parmlist.object(11).val,
# mrf.p.pf.parmlist.object(12).val,
# mrf.p.pf.parmlist.object(13).val,
# mrf.p.pf.parmlist.object(14).val,
# mrf.p.pf.parmlist.object(15).val, 
# mrf.p.pf.parmlist.object(16).val,
# mrf.p.pf.parmlist.object(17).val,
# mrf.p.pf.parmlist.object(18).val,
# mrf.p.pf.parmlist.object(19).val,
# mrf.p.pf.parmlist.object(20).val,
# error_value_final0)
# paramnames = ("kCa1", "kCa0", "ka1", "ka0", "kg1", "kg0", "kcdd1", "kcdd0", "kd1", "kd0", "k1M", "k0M", "ka1M", "ka0M", "kg1M", "kg0M", "kcdd1M", "kcdd0M", "kd1M", "kd0M", "nrecepts", "Least squares error")

# %% [markdown]
# Check that your table has the correct values in the correct places:

# %%
# print(mrf.p.pf.parmlist.o(4).name, mrf.p.pf.parmlist.o(4).val) #Shows that params have been added to parmlist
# print(mrf.p.pf.parmlist.o(20).name, mrf.p.pf.parmlist.o(20).val)
# Out:
# CaPlaneNMDARwMem[0].kg1 0.071
# CaPlaneNMDARwMem[0].nrecepts 3.5002494738620378

# %% [markdown]
# Export the table:

# %%
# valuelist = list(paramvalues)
# namelist = list(paramnames)
# paramdata = {'Parameter':paramnames, 'value':paramvalues}
# paramdf = pd.DataFrame(paramdata)
# paramdf.to_csv('optparamsMem10.csv', index = False)
# paramdf
# Out:
#               Parameter          value
# 0                  kCa1  100000.000000
# 1                  kCa0    8200.000000
# 2                   ka1       0.005000
# 3                   ka0       0.025000
# 4                   kg1       0.071000
# 5                   kg0       0.305000
# 6                 kcdd1       0.000766
# 7                 kcdd0       0.000648
# 8                   kd1       0.000079
# 9                   kd0       0.000168
# 10                  k1M       0.030000
# 11                  k0M       0.131620
# 12                 ka1M       0.005000
# 13                 ka0M       0.025000
# 14                 kg1M       0.071000
# 15                 kg0M       0.305000
# 16               kcdd1M       0.001800
# 17               kcdd0M       0.000331
# 18                 kd1M       0.000301
# 19                 kd0M       0.000168
# 20             nrecepts       3.500249
# 21  Least squares error       0.009293

# %% [markdown]
# Save optimized simulation data for later plotting, etc.:

# %%
# # save optimized simulation data
# simiopt = np.array(im)
# np.save('simiopt10CaNMDARplanesMem.npy', simiopt)
